# %%
from bs4 import BeautifulSoup as bs
import requests
import csv
import lxml

# %%
#pip install requests

# %%
#pip install beautiful soup
url = "https://www.amazon.in/soundcore-Bluetooth-Headphones-Cancelling-Personalization/dp/B0C3HCD34R/ref=sr_1_1_sspa?adgrpid=94186271211&dib=eyJ2IjoiMSJ9.RLIQRM6sOVMlDOzusP_ij-Ww8n2MafwIe3UytmyF8jedJr4Glb3Yuj7gaqMawRXYo6bZb3gourbeJyEPaTMoAiHcVxgjXuKYmHM_Yz6KeLkZLbdcNoq-YtI8L2CFBI56xSd4FS6Gml5A3Otbsz6mOpdD-b6Ho_wM29l0zFSLX1_i207aAioNf7Bt9s7-R9JKs_Q1Np6BelVoN_0aGMocaba0SiKtPKIvdpv1suJrLeY.KLKESE7HIdp4O4J098xEdQ9Jfoa8z5q3A1XR3HS1sNw&dib_tag=se&ext_vrnc=hi&hvadid=590474938788&hvdev=c&hvlocphy=1007819&hvnetw=g&hvqmt=e&hvrand=14830529747715890769&hvtargid=kwd-299624372049&hydadcr=21657_2254852&keywords=headphones&mcid=2731b644618e37489e08c2d407a4da57&qid=1760006468&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1"
header ={"user-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36"}

response = requests.get(url, headers = header)
if response.status_code == 200:

    html_content = response.text

else:
    print("fetching error")

#print(html_content)

# %%
soup = bs(html_content, "lxml")

# %%
#print(soup.prettify())

# %%
product_name = soup.find("span" , id="productTitle").text.strip()

# %%
print(product_name)
# Out:
# soundcore by Anker Q20i Wireless Bluetooth Over-Ear Headphones with Hybrid Active Noise Cancelling, 40h Playtime in ANC Mode, Hi-Res Audio, Deep Bass, Personalization via App (Black)

# %%
product_price = soup.find("span" , class_="a-price-whole").text.strip()

# %%
print(product_price)
# Out:
# 3,659.

# %%
product_sound = soup.find("span" , class_="a-size-base po-break-word").text.strip()

# %%
print(product_sound)
# Out:
# soundcore

# %%
product_title = soup.find("span", id="productTitle").text.strip()
product_price = soup.find("span", class_="a-price-whole").text.strip()
product_rating = soup.find("span", id="acrPopover").text.strip()
product_bp = soup.find("ul", class_="a-unordered-list a-vertical a-spacing-mini").text.strip()
product_description = soup.find("p", class_="a-spacing-small").text.strip()
reviews = soup.find("ul", id="cm-cr-dp-review-list").text.strip()

# %%
with open ("output.csv", mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["product_title", "product_price", "product_rating", "product_bp", "product_description", "reviews"])
    writer.writerow([product_title, product_price, product_rating, product_bp, product_description, reviews])

print("data saved")
# Out:
# data saved
